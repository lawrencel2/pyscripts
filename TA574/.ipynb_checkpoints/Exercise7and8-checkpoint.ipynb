# %% [markdown]
# # Exercise 7 and 8
# by Lawrence Lechuga
# 02/24/21

# %% [markdown]
# ## Import packages

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import os
import numpy as np
import skimage as sk
from skimage import io, filters, exposure, segmentation
import SimpleITK as sitk

# %% [markdown]
# ### Create a SimpleITK based viewer
# We are using the GetArrayViewFromImage() function from Simple ITK in order to convert an simpleITK based image into a numpy ndarray that we can view using matplotlib's pyplot.imshow.
#
# ***SimpleITK Image notes:***
# 1. We can get help on any of these modules using: >>> help('ModuleName').
# 2. SimpleITK imaging basics for those interested
#     - http://insightsoftwareconsortium.github.io/SimpleITK-Notebooks/Python_html/01_Image_Basics.html
#     - http://insightsoftwareconsortium.github.io/SimpleITK-Notebooks/Python_html/02_Pythonic_Image.html

# %%
def sitkshow(img):
    nda = sitk.GetArrayViewFromImage(img)
    plt.imshow(nda,cmap='gray')

# %% [markdown]
# ### Set Path to image
# Set your path to the appropriate image in the cell below.
#
# Note: If this work is being launched from mybinder, then path should be set correctly from the start.

# %%
image_path = 'ITK_Images/'
img = 'BrainProtonDensitySlice6.png'
filename = os.path.join(image_path,img)

# %% [markdown]
# ### Read in image and display
# We will first read in the image using sitk.ReadImage() function.
# I will load the "BrainProtonDensitySlice6.png" in as sitk based 32-bit float, or "sitk.sitkFloat32", then display using our custom function.

# %%
brain = sitk.ReadImage(filename,sitk.sitkFloat64)
I0 = sitkshow(brain)
plt.title('Original PD Brain Image',fontsize =18)
plt.show()

# %% [markdown]
# ## 1. Preprocessing
# In order to have a segmentation algorithm that performs optimally, we will need to process the images prior to segmentation. Lets start with smoothing the image.
# ### 1.1. Reduce Noise
# We will reduce noise by using SimpleITK's "Curvature anisotropic diffusion image filter". The module SimpleITK.CurvatureAnisotropicDiffusionImageFilter() is a class that mimics (or is a proxy of) C++ itk::simple::CurvatureAnisoptropicDiffusionImageFilter class.
#
# This python class object that I define below as CADIF, has many methods within it. If youre unfamiliar with classes and objects, think of it as a more efficiently way of grouping functionality and data together. If interested, https://docs.python.org/3/tutorial/classes.html has a great description of classes.
#
# #### Action Required:
# Have students set different attributes and try different values.

# %%
CADIF = sitk.CurvatureAnisotropicDiffusionImageFilter()
CADIF.SetTimeStep(0.125)
CADIF.SetNumberOfIterations(5)
CADIF.SetConductanceParameter(9.0)
brain_filt = CADIF.Execute(brain)
I1 = sitkshow(brain_filt)
plt.title('CADIF Brain Image',fontsize =18)
plt.show()
print(CADIF)
# Out:
# itk::simple::CurvatureAnisotropicDiffusionImageFilter
#   TimeStep: 0.125
#   ConductanceParameter: 9
#   ConductanceScalingUpdateInterval: 1
#   NumberOfIterations: 5
#   Debug: 0
#   NumberOfThreads: 4
#   NumberOfWorkUnits: 0
#   Commands: (none)
#   ProgressMeasurement: 1
#   ActiveProcess: (none)

# %% [markdown]
# ### 1.2. Create a gradient image
# Now that our image is filtered to remove some noise, we can determine our edges much more effectively. To find the edges of our image we will be using SimpleITK's "Gradient Magnitude Recursive Gaussian Image Filter".  The module SimpleITK.GradientMagnitudeRecursiveGaussianImageFilter() is a class that mimics (or is a proxy of) C++ itk::simple::GradientMagnitudeRecursiveGaussianImageFilter class. As you can see, very similar to the structure of the previous section.
#
# #### Action Required:
# Create something for the students to do here. Possibly have them show different values of sigma in a subplot?

# %%
GF = sitk.GradientMagnitudeRecursiveGaussianImageFilter()
GF.SetSigma(1.0)
brain_edge = GF.Execute(brain_filt)
I2 =sitkshow(brain_edge)
plt.title('Gradient Brain Image',fontsize =18)
plt.show()
print(GF)
# Out:
# itk::simple::GradientMagnitudeRecursiveGaussianImageFilter
#   Sigma: 1
#   NormalizeAcrossScale: 0
#   Debug: 0
#   NumberOfThreads: 4
#   NumberOfWorkUnits: 0
#   Commands: (none)
#   ProgressMeasurement: 1
#   ActiveProcess: (none)

# %% [markdown]
# ### 1.3. Normalize magnitude
# Lastly, we will normalize the magnitude using a sigmoid filter. This filter will take in each pixel and tranform its value based on the sigmoid function:
# \begin{equation}
# f(x) = (Max - Min)\cdot \frac{1}{1+ e^{-\frac{x-\beta}{\alpha}}}+ Min
# \end{equation}
# In the cell below, we can visualize how different parameters will affect the sigmoid response:

# %%
# small function to visualize the parameter effects
def sigmoid(MIN=0.0, MAX=1.0, ALPHA=-0.3, BETA=2.0):
    X = np.linspace(-10,10,100)
    Y = (MAX-MIN)*1/(1+np.exp(-(X-BETA)/ALPHA))+MIN
    return X,Y
x, y = sigmoid()

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.plot(x,y, 'r',linewidth=3.0)
plt.show()

# %% [markdown]
# #### SigmoidImageFilter
# Now we can input out gradient image into the sigmoid image filter that is controlled by SimpleITK's SigmoidImageFilter() class. This will normalize the gradient image for later segmentation.

# %%
#help(sitk.SigmoidImageFilter)
SIF = sitk.SigmoidImageFilter()
SIF.SetOutputMaximum(1.0)
SIF.SetOutputMinimum(0.0)
SIF.SetAlpha(-0.3)
SIF.SetBeta(2.0)
brain_processed = SIF.Execute(brain_edge)
brain_processed = sitk.Cast(brain_processed, sitk.sitkFloat64)
I3 =sitkshow(brain_processed)
plt.title('Processed Brain Image',fontsize =18)
plt.show()
print(SIF)
# Out:
# itk::simple::SigmoidImageFilter
#   Alpha: -0.3
#   Beta: 2
#   OutputMaximum: 1
#   OutputMinimum: 0
#   Debug: 0
#   NumberOfThreads: 4
#   NumberOfWorkUnits: 0
#   Commands: (none)
#   ProgressMeasurement: 1
#   ActiveProcess: (none)

# %% [markdown]
# ## 2. Segmentation
# Now we can take our preprocessed image and apply our segmentation algorithm of choice.

# %%
FM = sitk.FastMarchingImageFilter()
seedValue = 0
stoppingValue = 100
seedPosition = (int(56), int(96))
trialPoint = (seedPosition[0], seedPosition[1],seedValue)
FM.AddTrialPoint(trialPoint)
FM.SetStoppingValue(100)

print(FM)

GAC = sitk.GeodesicActiveContourLevelSetImageFilter()
GAC.SetPropagationScaling(10.0)
GAC.SetCurvatureScaling(1.0)
GAC.SetAdvectionScaling(1.0)
GAC.SetMaximumRMSError(0.02)
GAC.SetNumberOfIterations(500)

B = FM.Execute(brain_processed)
C = GAC.Execute(FM.Execute(brain_processed),brain_processed)


sitkshow(B)
plt.title('Segmented',fontsize =18)
plt.show()
# print(GAC)
# Out:
# itk::simple::FastMarchingImageFilter
#   TrialPoints: [ [ 56, 96, 0 ] ]
#   NormalizationFactor: 1
#   StoppingValue: 100
#   Debug: 0
#   NumberOfThreads: 4
#   NumberOfWorkUnits: 0
#   Commands: (none)
#   ProgressMeasurement: 0
#   ActiveProcess: (none)

# %%
#help(sitk.FastMarchingBaseImageFilter)
help(sitk.GeodesicActiveContourLevelSetImageFilter)
# Out:
# Help on class GeodesicActiveContourLevelSetImageFilter in module SimpleITK.SimpleITK:
#
# class GeodesicActiveContourLevelSetImageFilter(ImageFilter)
#  |  Proxy of C++ itk::simple::GeodesicActiveContourLevelSetImageFilter class.
#  |
#  |  Method resolution order:
#  |      GeodesicActiveContourLevelSetImageFilter
#  |      ImageFilter
#  |      ProcessObject
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  Execute(self, initialImage, featureImage)
#  |      Execute(GeodesicActiveContourLevelSetImageFilter self, Image initialImage, Image featureImage) -> Image
#  |
#  |  GetAdvectionScaling(self)
#  |      GetAdvectionScaling(GeodesicActiveContourLevelSetImageFilter self) -> double
#  |
#  |  GetCurvatureScaling(self)
#  |      GetCurvatureScaling(GeodesicActiveContourLevelSetImageFilter self) -> double
#  |
#  |  GetElapsedIterations(self)
#  |      GetElapsedIterations(GeodesicActiveContourLevelSetImageFilter self) -> uint32_t
#  |
#  |  GetMaximumRMSError(self)
#  |      GetMaximumRMSError(GeodesicActiveContourLevelSetImageFilter self) -> double
#  |
#  |  GetName(self)
#  |      GetName(GeodesicActiveContourLevelSetImageFilter self) -> std::string
#  |
#  |  GetNumberOfIterations(self)
#  |      GetNumberOfIterations(GeodesicActiveContourLevelSetImageFilter self) -> uint32_t
#  |
#  |  GetPropagationScaling(self)
#  |      GetPropagationScaling(GeodesicActiveContourLevelSetImageFilter self) -> double
#  |
#  |  GetRMSChange(self)
#  |      GetRMSChange(GeodesicActiveContourLevelSetImageFilter self) -> double
#  |
#  |  GetReverseExpansionDirection(self)
#  |      GetReverseExpansionDirection(GeodesicActiveContourLevelSetImageFilter self) -> bool
#  |
#  |  ReverseExpansionDirectionOff(self)
#  |      ReverseExpansionDirectionOff(GeodesicActiveContourLevelSetImageFilter self)
#  |
#  |  ReverseExpansionDirectionOn(self)
#  |      ReverseExpansionDirectionOn(GeodesicActiveContourLevelSetImageFilter self)
#  |
#  |  SetAdvectionScaling(self, AdvectionScaling)
#  |      SetAdvectionScaling(GeodesicActiveContourLevelSetImageFilter self, double AdvectionScaling)
#  |
#  |  SetCurvatureScaling(self, CurvatureScaling)
#  |      SetCurvatureScaling(GeodesicActiveContourLevelSetImageFilter self, double CurvatureScaling)
#  |
#  |  SetMaximumRMSError(self, MaximumRMSError)
#  |      SetMaximumRMSError(GeodesicActiveContourLevelSetImageFilter self, double MaximumRMSError)
#  |
#  |  SetNumberOfIterations(self, NumberOfIterations)
#  |      SetNumberOfIterations(GeodesicActiveContourLevelSetImageFilter self, uint32_t NumberOfIterations)
#  |
#  |  SetPropagationScaling(self, PropagationScaling)
#  |      SetPropagationScaling(GeodesicActiveContourLevelSetImageFilter self, double PropagationScaling)
#  |
#  |  SetReverseExpansionDirection(self, ReverseExpansionDirection)
#  |      SetReverseExpansionDirection(GeodesicActiveContourLevelSetImageFilter self, bool ReverseExpansionDirection)
#  |
#  |  __init__(self)
#  |      __init__(GeodesicActiveContourLevelSetImageFilter self) -> GeodesicActiveContourLevelSetImageFilter
#  |
#  |  __repr__ = _swig_repr(self)
#  |
#  |  __str__(self)
#  |      __str__(GeodesicActiveContourLevelSetImageFilter self) -> std::string
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __swig_destroy__ = delete_GeodesicActiveContourLevelSetImageFilter(...)
#  |      delete_GeodesicActiveContourLevelSetImageFilter(GeodesicActiveContourLevelSetImageFilter self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  thisown
#  |      The membership flag
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from ProcessObject:
#  |
#  |  Abort(self)
#  |      Abort(ProcessObject self)
#  |
#  |  AddCommand(self, *args)
#  |      AddCommand(ProcessObject self, itk::simple::EventEnum event, Command cmd) -> int
#  |      AddCommand(ProcessObject self, itk::simple::EventEnum e, PyObject * obj) -> int
#  |
#  |  DebugOff(self)
#  |      DebugOff(ProcessObject self)
#  |
#  |  DebugOn(self)
#  |      DebugOn(ProcessObject self)
#  |
#  |  GetDebug(self)
#  |      GetDebug(ProcessObject self) -> bool
#  |
#  |  GetNumberOfThreads(self)
#  |      GetNumberOfThreads(ProcessObject self) -> unsigned int
#  |
#  |  GetNumberOfWorkUnits(self)
#  |      GetNumberOfWorkUnits(ProcessObject self) -> unsigned int
#  |
#  |  GetProgress(self)
#  |      GetProgress(ProcessObject self) -> float
#  |
#  |  HasCommand(self, event)
#  |      HasCommand(ProcessObject self, itk::simple::EventEnum event) -> bool
#  |
#  |  RemoveAllCommands(self)
#  |      RemoveAllCommands(ProcessObject self)
#  |
#  |  SetDebug(self, debugFlag)
#  |      SetDebug(ProcessObject self, bool debugFlag)
#  |
#  |  SetNumberOfThreads(self, n)
#  |      SetNumberOfThreads(ProcessObject self, unsigned int n)
#  |
#  |  SetNumberOfWorkUnits(self, n)
#  |      SetNumberOfWorkUnits(ProcessObject self, unsigned int n)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from ProcessObject:
#  |
#  |  GetGlobalDefaultCoordinateTolerance()
#  |      GetGlobalDefaultCoordinateTolerance() -> double
#  |
#  |  GetGlobalDefaultDebug()
#  |      GetGlobalDefaultDebug() -> bool
#  |
#  |  GetGlobalDefaultDirectionTolerance()
#  |      GetGlobalDefaultDirectionTolerance() -> double
#  |
#  |  GetGlobalDefaultNumberOfThreads()
#  |      GetGlobalDefaultNumberOfThreads() -> unsigned int
#  |
#  |  GetGlobalDefaultThreader()
#  |      GetGlobalDefaultThreader() -> std::string
#  |
#  |  GetGlobalWarningDisplay()
#  |      GetGlobalWarningDisplay() -> bool
#  |
#  |  GlobalDefaultDebugOff()
#  |      GlobalDefaultDebugOff()
#  |
#  |  GlobalDefaultDebugOn()
#  |      GlobalDefaultDebugOn()
#  |
#  |  GlobalWarningDisplayOff()
#  |      GlobalWarningDisplayOff()
#  |
#  |  GlobalWarningDisplayOn()
#  |      GlobalWarningDisplayOn()
#  |
#  |  SetGlobalDefaultCoordinateTolerance(arg1)
#  |      SetGlobalDefaultCoordinateTolerance(double arg1)
#  |
#  |  SetGlobalDefaultDebug(debugFlag)
#  |      SetGlobalDefaultDebug(bool debugFlag)
#  |
#  |  SetGlobalDefaultDirectionTolerance(arg1)
#  |      SetGlobalDefaultDirectionTolerance(double arg1)
#  |
#  |  SetGlobalDefaultNumberOfThreads(n)
#  |      SetGlobalDefaultNumberOfThreads(unsigned int n)
#  |
#  |  SetGlobalDefaultThreader(threader)
#  |      SetGlobalDefaultThreader(std::string const & threader) -> bool
#  |
#  |  SetGlobalWarningDisplay(flag)
#  |      SetGlobalWarningDisplay(bool flag)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from ProcessObject:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
