# %% [markdown]
# # ITK Exercise 4: Demons registration
# Lawrence Lechuga
# 03/31/21

# %% [markdown]
# ### Import Packages
# Here we will be using SimpleITK again. This library has multiple demons registation classes available to use.
# First we will:
# - Import appropriate packages
# - Load in two liver images at different points in the respiratory cycle
# - Define a function that will allow us to track the metric value with each iteration.

# %%
import SimpleITK as sitk
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

file1 = 'ITK_Images/liver_exp.png'
file2 = 'ITK_Images/liver_insp.png'
fixed = sitk.ReadImage(file1, sitk.sitkFloat32)
Moving = sitk.ReadImage(file2, sitk.sitkFloat32)
moving = Moving
def command_iteration(filter,print_flag):
    if print_flag == 1:
        print(f"{filter.GetElapsedIterations():3} = {filter.GetMetric():10.5f}")
    cost.append(filter.GetMetric())

# %% [markdown]
# ### Demons Registration
# Demons is a form of Difformable image registration (DIR)
# ***Explanation of Demons origin***
#
# Below we will:
# 1. Prepocess the images using histogram image matching. Various parameters are set to perform this.
# 2. Parameters, such as iterations and gaussian smoothing $\sigma$, are set for our demons registration
# 3. Create an instance of histogram matching image filter and execute with appropriate parameters
# 4. An instance of the demons registration filter is then created and parameters are assigned
# 5. The demons algorithm is then executed for our images. This will create a displacement field that will be updated as the similarity metric (cost function) is minimized. We will see the cost function values print for each iteration
# 6. Upon completion our final displacement field will be used to create our overal transformation, outTx
# 7. Lastly, we can apply the transform to the moving image and resample.

# %%
cost = []
print_flag = 0 # 1 to print cost func at each iteration, 0 to suppress.
# 1. Initialize parameters for histogram matching
hist_levels = 1024
match_points = 7
matcher = sitk.HistogramMatchingImageFilter()

# 2. Initialize parameters for Demons
its = 500 # iterations for demons
sig = 1.0 # standard deviation 

# 3. Assign params and execute histogram match filter
matcher.SetNumberOfHistogramLevels(hist_levels)
matcher.SetNumberOfMatchPoints(match_points)
matcher.ThresholdAtMeanIntensityOn()
moving = matcher.Execute(moving, fixed)

# 4. Assign params and execute demons registration image filter
demons = sitk.DemonsRegistrationFilter()
demons.SetNumberOfIterations(500)
demons.SetStandardDeviations(1.0)
demons.AddCommand(sitk.sitkIterationEvent, lambda: command_iteration(demons,print_flag))
# 5. Run demons
displacementField = demons.Execute(fixed, moving)
print("-------")
print(f"Number Of Iterations: {demons.GetElapsedIterations()}")
print(f" RMS: {demons.GetRMSChange()}")

# 6. Create overall transform 
outTx = sitk.DisplacementFieldTransform(displacementField)
cost.append(demons.GetMetric())

# 7. Resample the image 
resampler = sitk.ResampleImageFilter()
resampler.SetReferenceImage(fixed)
resampler.SetInterpolator(sitk.sitkLinear)
resampler.SetDefaultPixelValue(100)
resampler.SetTransform(outTx)
out = resampler.Execute(moving)
#
print(demons)
# Out:
# -------
# Number Of Iterations: 500
#  RMS: 0.25384405908971996
# itk::simple::DemonsRegistrationFilter
#   StandardDeviations: [ 1, 1, 1 ]
#   NumberOfIterations: 500
#   MaximumRMSError: 0.02
#   UseMovingImageGradient: 0
#   SmoothDisplacementField: 1
#   SmoothUpdateField: 0
#   UpdateFieldStandardDeviations: [ 1, 1, 1 ]
#   MaximumKernelWidth: 30
#   MaximumError: 0.1
#   IntensityDifferenceThreshold: 0.001
#   UseImageSpacing: 1
#   ElapsedIterations: 500
#   RMSChange: 0.253844
#   Metric: 79.5395
#   Debug: 0
#   NumberOfThreads: 4
#   NumberOfWorkUnits: 0
#   Commands:
#     Event: IterationEvent Command: Command
#   ProgressMeasurement: 0
#   ActiveProcess:
#     DemonsRegistrationFilter (0x7fe355405630)
#       RTTI typeinfo:   itk::DemonsRegistrationFilter<itk::Image<float, 2u>, itk::Image<float, 2u>, itk::Image<itk::Vector<double, 2u>, 2u> >
#       Reference Count: 1
#       Modified Time: 427061
#       Debug: Off
#       Object Name:
#       Observers:
#         DeleteEvent(SimpleMemberCommand)
#         IterationEvent(SimpleAdaptorCommand "Command IterationEvent")
#       Inputs:
#         FixedImage: (0x7fe355618230) *
#         InitialDisplacementField: (0x0)
#         MovingImage: (0x7fe3556f7620) *
#       Indexed Inputs:
#         0: InitialDisplacementField (0x0)
#         1: FixedImage (0x7fe355618230)
#         2: MovingImage (0x7fe3556f7620)
#       Required Input Names: FixedImage, MovingImage
#       NumberOfRequiredInputs: 0
#       Outputs:
#         Primary: (0x7fe35784bc20)
#       Indexed Outputs:
#         0: Primary (0x7fe35784bc20)
#       NumberOfRequiredOutputs: 1
#       Number Of Work Units: 16
#       ReleaseDataFlag: Off
#       ReleaseDataBeforeUpdateFlag: Off
#       AbortGenerateData: Off
#       Progress: 1
#       Multithreader:
#         RTTI typeinfo:   itk::PoolMultiThreader
#         Reference Count: 1
#         Modified Time: 408012
#         Debug: Off
#         Object Name:
#         Observers:
#           none
#         Number of Work Units: 16
#         Number of Threads: 4
#         Global Maximum Number Of Threads: 128
#         Global Default Number Of Threads: 4
#         Global Default Threader Type: itk::MultiThreaderBaseEnums::Threader::Pool
#         SingleMethod: 1
#         SingleData: 0x7ffeef61c428
#       DynamicMultiThreading: On
#       CoordinateTolerance: 1e-06
#       DirectionTolerance: 1e-06
#       InPlace: Off
#       The input and output to this filter are the same type. The filter can be run in place.
#       ElapsedIterations: 500
#       UseImageSpacing: On
#       State: UNINITIALIZED
#       MaximumRMSError: 0.02
#       NumberOfIterations: 500
#       ManualReinitialization: 0
#       RMSChange: 0.253844
#
#       DifferenceFunction:
#         DemonsRegistrationFunction (0x7fe355452830)
#           RTTI typeinfo:   itk::DemonsRegistrationFunction<itk::Image<float, 2u>, itk::Image<float, 2u>, itk::Image<itk::Vector<double, 2u>, 2u> >
#           Reference Count: 1
#           Radius: [0, 0]
#           ScaleCoefficients: 0x7fe355452850          MovingImage: 0x7fe3556f7620
#           FixedImage: 0x7fe355618230
#           MovingImageIterpolator: 0x7fe357eb4b60
#           FixedImageGradientCalculator: 0x7fe357e68390
#           DenominatorThreshold: 1e-09
#           IntensityDifferenceThreshold: 0.001
#           UseMovingImageGradient: 0
#           Metric: 79.5395
#           SumOfSquaredDifference: 2.08508e+07
#           NumberOfPixelsProcessed: 262144
#           RMSChange: 0.253844
#           SumOfSquaredChange: 16891.7
#
#       Smooth deformation field: on
#       Standard deviations: [1, 1]
#       Smooth update field: off
#       Update field standard deviations: [1, 1]
#       StopRegistrationFlag: 0
#       MaximumError: 0.1
#       MaximumKernelWidth: 30
#       UseMovingImageGradient: 0
#       Intensity difference threshold: 0.001

# %% [markdown]
# ### Display Results
# Now that we have performed the registration, we can display the results!

# %%
fig, axs = plt.subplots(2,3,figsize = (20,20))
its = np.linspace(1,demons.GetElapsedIterations(),num=demons.GetElapsedIterations())
img_fix = sitk.GetArrayFromImage(fixed)
img_mov = sitk.GetArrayFromImage(moving)
img_out = sitk.GetArrayFromImage(out)

axs[0,0].imshow(img_fix,cmap='gray'); axs[0,0].axis('off'); axs[0,0].set_title('Liver Expiration',fontsize=16)
axs[0,1].imshow(img_mov,cmap='gray'); axs[0,1].axis('off'); axs[0,1].set_title('Liver Inspiration',fontsize=16)
axs[0,2].imshow(img_out,cmap='gray'); axs[0,2].axis('off'); axs[0,2].set_title('Transformed Liver',fontsize=16)
axs[1,0].imshow(img_fix-img_mov,cmap='gray'); axs[1,0].axis('off'); axs[1,0].set_title('Fixed-Moving',fontsize=16)
axs[1,1].imshow(img_fix-img_out,cmap='gray'); axs[1,1].axis('off'); axs[1,1].set_title('Fixed-Transformed',fontsize=16)

axs[1,2].plot(cost,'r',linewidth=3.0);
axs[1,2].set_title('Demons Cost Function Evolution',fontsize=14);axs[1,2].set_xlabel('Iteration',fontsize=14);
axs[1,2].set_ylabel("Cost function",fontsize=14); 


plt.show()

# %%
X = sitk.GetArrayFromImage(moving)
Y = sitk.GetArrayFromImage(Moving)
F = sitk.GetArrayFromImage(fixed)
XX = np.hstack(X)
YY = np.hstack(Y)
FF = np.hstack(F)

fig, (ax1,ax2,ax3,ax4,ax5) = plt.subplots(1,5,figsize = (15,5))
ax1.hist(FF,color ='r',bins='auto')
ax2.hist(YY,color ='b',bins='auto')
ax3.hist(XX,color ='g',bins='auto')
ax4.hist(YY-FF,color ='g',bins='auto')
ax5.hist(XX-FF,color ='g',bins='auto')


plt.show()
